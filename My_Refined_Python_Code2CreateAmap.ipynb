# %% [markdown]
# My refined Python code to create a map by Worachat Wannawong, Ph.D., incorporating best practices and addressing potential issues:

# %%
import folium

# Define map center coordinates (New York City)
map_center = [40.7128, -74.0060]  # Corrected longitude for New York City

# Create a base map with zoom level 12
mymap = folium.Map(location=map_center, zoom_start=12)

# Create a marker for New York City with a blue info sign icon and a popup
marker = folium.Marker(
    location=map_center,
    popup="New York City",
    icon=folium.Icon(color="blue", prefix="fa", icon="info-sign")
)

# Add the marker to the map
marker.add_to(mymap)

# Display the map (no need for IPython.display since folium handles it)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f4a65ac16cd89245aa918b330f139e3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f4a65ac16cd89245aa918b330f139e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f4a65ac16cd89245aa918b330f139e3 = L.map(
#                 &quot;map_8f4a65ac16cd89245aa918b330f139e3&quot;,
#                 {
#                     center: [40.7128, -74.006],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f5b66c5ac9a9a2635be9c3eba60e8b54 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f5b66c5ac9a9a2635be9c3eba60e8b54.addTo(map_8f4a65ac16cd89245aa918b330f139e3);
#
#
#             var marker_7ec1494d51e4eb64cf4369b47a1b5695 = L.marker(
#                 [40.7128, -74.006],
#                 {}
#             ).addTo(map_8f4a65ac16cd89245aa918b330f139e3);
#
#
#             var icon_bac9d1065358b2d92d936c85548befd8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7ec1494d51e4eb64cf4369b47a1b5695.setIcon(icon_bac9d1065358b2d92d936c85548befd8);
#
#
#         var popup_58f8431be0989200b24242a829448231 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f627ebcaa7166e86605620b04ab7060b = $(`&lt;div id=&quot;html_f627ebcaa7166e86605620b04ab7060b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York City&lt;/div&gt;`)[0];
#                 popup_58f8431be0989200b24242a829448231.setContent(html_f627ebcaa7166e86605620b04ab7060b);
#
#
#
#         marker_7ec1494d51e4eb64cf4369b47a1b5695.bindPopup(popup_58f8431be0989200b24242a829448231)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Here's a breakdown of the improvements:
#
# - **Clarity and Conciseness:** The code is well-formatted and uses clear variable names, making it easy to understand.
# - **Corrected Longitude:** The `map_center` now has the correct longitude (-74.0060) for New York City.
# - **Modern Icon Style:** The `icon` argument in `folium.Marker` uses the `prefix="fa"` and `icon="info-sign"` syntax for a more recent and widely supported FontAwesome icon style.
# - **Direct Display:** The `display(mymap)` line is removed as folium handles displaying the map automatically.
# - **Error Handling (Optional):** Consider adding a `try-except` block to gracefully handle potential errors during map creation:

# %%
import folium

# Define map center coordinates (Matthayom Wat Nongkhaem School)
map_center = [13.676519, 100.3372947]  # Corrected longitude for Matthayom Wat Nongkhaem School

# Create a base map with zoom level 12
mymap = folium.Map(location=map_center, zoom_start=12)

# Create a marker for Matthayom Wat Nongkhaem School with a blue info sign icon and a popup
marker = folium.Marker(
    location=map_center,
    popup="New York City",
    icon=folium.Icon(color="blue", prefix="fa", icon="info-sign")
)

# Add the marker to the map
marker.add_to(mymap)

# Display the map (no need for IPython.display since folium handles it)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ad11971c4b65e644e1b651f459a203c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ad11971c4b65e644e1b651f459a203c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ad11971c4b65e644e1b651f459a203c = L.map(
#                 &quot;map_4ad11971c4b65e644e1b651f459a203c&quot;,
#                 {
#                     center: [13.676519, 100.3372947],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_415dde6facf84d761fe6dc0f2751aa8c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_415dde6facf84d761fe6dc0f2751aa8c.addTo(map_4ad11971c4b65e644e1b651f459a203c);
#
#
#             var marker_3d9cef27ae8edc1b2e0f97f3b67b032a = L.marker(
#                 [13.676519, 100.3372947],
#                 {}
#             ).addTo(map_4ad11971c4b65e644e1b651f459a203c);
#
#
#             var icon_5733f727b7f3713c3666ee74c512b9a5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3d9cef27ae8edc1b2e0f97f3b67b032a.setIcon(icon_5733f727b7f3713c3666ee74c512b9a5);
#
#
#         var popup_b2eaba750d0d313f17e4937ff7f89bd7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d9b8fc4dba3ac121756ba39d40b3bee = $(`&lt;div id=&quot;html_7d9b8fc4dba3ac121756ba39d40b3bee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;New York City&lt;/div&gt;`)[0];
#                 popup_b2eaba750d0d313f17e4937ff7f89bd7.setContent(html_7d9b8fc4dba3ac121756ba39d40b3bee);
#
#
#
#         marker_3d9cef27ae8edc1b2e0f97f3b67b032a.bindPopup(popup_b2eaba750d0d313f17e4937ff7f89bd7)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

# Define map center coordinates (Matthayom Wat Nongkhaem School)
map_center = [13.676519, 100.3372947]  # Corrected longitude for Matthayom Wat Nongkhaem School

# Create a base map with zoom level 12
mymap = folium.Map(location=map_center, zoom_start=12)

# Create a marker for Matthayom Wat Nongkhaem School with a blue info sign icon and a popup
marker = folium.Marker(
    location=map_center,
    popup="Matthayom Wat Nongkhaem School",
    icon=folium.Icon(color="blue", prefix="fa", icon="info-sign")
)

# Add the marker to the map
marker.add_to(mymap)

# Display the map (no need for IPython.display since folium handles it)
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f0ab27b48537526fdac9bc470a157be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f0ab27b48537526fdac9bc470a157be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f0ab27b48537526fdac9bc470a157be = L.map(
#                 &quot;map_8f0ab27b48537526fdac9bc470a157be&quot;,
#                 {
#                     center: [13.676519, 100.3372947],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b903627326f8830c2e5d052c6fbc1c3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7b903627326f8830c2e5d052c6fbc1c3.addTo(map_8f0ab27b48537526fdac9bc470a157be);
#
#
#             var marker_987e10131597e835df08fa2d69f3bd9c = L.marker(
#                 [13.676519, 100.3372947],
#                 {}
#             ).addTo(map_8f0ab27b48537526fdac9bc470a157be);
#
#
#             var icon_fceb7d6bf719bca69400d21c2de1b9ce = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_987e10131597e835df08fa2d69f3bd9c.setIcon(icon_fceb7d6bf719bca69400d21c2de1b9ce);
#
#
#         var popup_8db4e9a47d8cfb7ffb71c8ac2b1fc2ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_51752b86a7fdc284d9b144b37d1f97d6 = $(`&lt;div id=&quot;html_51752b86a7fdc284d9b144b37d1f97d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Matthayom Wat Nongkhaem School&lt;/div&gt;`)[0];
#                 popup_8db4e9a47d8cfb7ffb71c8ac2b1fc2ed.setContent(html_51752b86a7fdc284d9b144b37d1f97d6);
#
#
#
#         marker_987e10131597e835df08fa2d69f3bd9c.bindPopup(popup_8db4e9a47d8cfb7ffb71c8ac2b1fc2ed)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Remember to install the `folium` library before running the code:
#
# ```bash
# pip install folium
# ```
#
# This refined code effectively creates a map centered on New York City and Matthayom Wat Nongkhaem School, Thailand with a blue info sign marker and a popup, providing a clear and visually appealing representation. URL: https://maps.app.goo.gl/R4YhN3XkbZAURPYy or  https://www.google.com/maps/place/โรงเรียนมัธยมวัดหนองแขม/@13.676519,100.3372947,839m/data=!3m1!1e3!4m14!1m7!3m6!1s0x30e2be0d6edb02a1:0xca5208e559090800!2z4LmC4Lij4LiH4LmA4Lij4Li14Lii4LiZ4Lih4Lix4LiY4Lii4Lih4Lin4Lix4LiU4Lir4LiZ4Lit4LiH4LmB4LiC4Lih!8m2!3d13.676519!4d100.3398696!16s%2Fg%2F1234td6l!3m5!1s0x30e2be0d6edb02a1:0xca5208e559090800!8m2!3d13.676519!4d100.3398696!16s%2Fg%2F1234td6l?entry=ttu
